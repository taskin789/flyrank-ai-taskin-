# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taskin789/flyrank-ai-taskin-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I chose the Machine Learning lane because I want to learn how data can help improve website performance. I am interested in finding patterns in search data and using them to support better content decisions. This project will help me improve my data analysis and machine learning skills through real-world practice.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My work helps decide which webpages should be improved to increase search performance. The people who act on this information are SEO analysts or content teams. A wrong recommendation could waste time improving the wrong pages and reduce opportunities to increase traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The sample dataset contains 5 rows and 3 columns. It provides a simple example for testing the notebook and verifying that the analysis code runs correctly. This dataset can be used to demonstrate basic data exploration before working with a larger real-world dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import pandas as pd

if os.path.exists("starter.csv"):
    df = pd.read_csv("starter.csv")
else:
    df = pd.DataFrame({
        "feature1": [10, 20, 30, 40, 50],
        "feature2": [15, 25, 35, 45, 55],
        "target": [0, 1, 0, 1, 1]
    })

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.head())
# Out:
# Rows: 5
# Columns: 3
#    feature1  feature2  target
# 0        10        15       0
# 1        20        25       1
# 2        30        35       0
# 3        40        45       1
# 4        50        55       1

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# This project can identify observed patterns and relationships in the data. The results will provide decision-support for improving website content. The findings cannot prove that one factor directly causes another, and they cannot predict how Google will rank webpages in the future.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
